# %%
import pandas as pd
import numpy as np

# %%
liverpool = pd.read_csv('/Users/rajibul/Downloads/DataAnalysis/EPL/Liverpool.csv')
liverpool.head()
# Out:
#                   Date        Opponent  Is_Home  Result  Goals  \
# 0  2013-08-17 14:45:00    Stoke City          1       1      1
# 1  2013-09-29 18:00:00      Sunderland        0       1      3
# 2  2013-11-02 19:30:00         Arsenal        0      -1      0
# 3  2013-12-01 16:05:00       Hull City        0      -1      1
# 4  2013-12-04 21:45:00  Norwich City          1       1      5
#
#    Opponent_Goals  Possession  Shots  Shots_On_Target  Passes_Completed  ...  \
# 0               0          55     25               11               430  ...
# 1               1          54     15                6               350  ...
# 2               2          46     12                4               436  ...
# 3               3          62      9                4               496  ...
# 4               1          62     28               12               526  ...
#
#    Opponent_Corners  Opponent_Crosses  Opponent_Fouls  Opponent_Offsides  \
# ...

# %%
liverpool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       699 non-null    object
#  1   Opponent                   699 non-null    object
#  2   Is_Home                    699 non-null    int64
#  3   Result                     699 non-null    int64
#  4   Goals                      699 non-null    int64
#  5   Opponent_Goals             699 non-null    int64
#  6   Possession                 699 non-null    int64
#  7   Shots                      699 non-null    int64
#  8   Shots_On_Target            699 non-null    int64
#  9   Passes_Completed           699 non-null    int64
#  10  Pass_Accuracy              699 non-null    int64
#  11  Corners                    699 non-null    int64
#  12  Crosses                    699 non-null    int64
# ...
